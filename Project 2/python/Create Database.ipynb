# %%
import pandas as pd
import pymongo

# %%
states_abbrev = ["AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DE", "FL", "GA", 
          "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA", "ME", "MD", 
          "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", 
          "NM", "NY", "NC", "ND", "OH", "OK", "OR", "PA", "RI", "SC", 
          "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"]

# %%
states = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# %%
Template_State = pd.DataFrame({"States":states,
                              "States_ab":states_abbrev});

# %%
Capital_Data = pd.read_csv("../data/50_states.csv")

# %%
Labor_Force_Data = pd.read_csv("../data/Labor Force Data.csv")

# %%
Combined_Data = Template_State.merge(Capital_Data, left_on = "States", right_on="GeoName")
Combined_Data = Combined_Data.merge(Labor_Force_Data, left_on = "States", right_on="State",how="inner")

Drop_Data = ["GeoName","LineCode","2017:Q1","2017:Q2","2017:Q3","State"]
Combined_Data = Combined_Data.drop(columns = Drop_Data)

# %%
Starbucks_Locations = pd.read_csv("../data/us_directory.csv")
Starbucks_Locations = Starbucks_Locations.merge(Template_State, left_on = "State/Province", right_on="States_ab")

Drop_Data = ["Unnamed: 0","Brand","Country","Postcode","Phone Number","Timezone","States_ab"]
Starbucks_Locations = Starbucks_Locations.drop(columns = Drop_Data)

# %%
API_Data = {}

States = Combined_Data["States"].tolist()
Labor_Force = Combined_Data["Labor Force"].tolist()
Personal_Income_Capital = Combined_Data["2017:Q4"].tolist()

# %%
API_Data = {}
for i in range(len(Combined_Data)):
    API_Data[States[i]] = {"Labor Force":Labor_Force[i],
                          "Personal Income Capital":Personal_Income_Capital[i]}

# %%
#For Each state
for state in states:
    #Find a dataframe with all the starbucks in that state
    Locations_in_State = Starbucks_Locations[Starbucks_Locations["States"]==state]
    #Creates a dictionary entry called "Stores" in each state
    API_Data[state]["Stores"] = {}
    Stores = API_Data[state]["Stores"]
    
    # For every store in "Locations_in_State" dataframe
    for store in Locations_in_State["Store Number"]:
        # Create a dictionary entry for the store number
        Stores[store] = {}
        Store_Number = Stores[store]
        # Finds the one data row corresponding to the store number
        Store_Information = Locations_in_State[Locations_in_State["Store Number"]==store]
        # Creates details for each store
        Store_Number["Ownership Type"] = Store_Information.iloc[0,2]
        Store_Number["Street Address"] = Store_Information.iloc[0,3]
        Store_Number["City"] = Store_Information.iloc[0,4]
        Store_Number["State"] = Store_Information.iloc[0,5]
        Store_Number["Longitude"] = Store_Information.iloc[0,6]
        Store_Number["Latitude"] = Store_Information.iloc[0,7]
    
#     API_Data[state]["Locations"]["Store Number"] =

# %% [markdown]
# #Import to MongoDB with PyMongo

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

Starbucks_Information_db = client.StarbucksDB
Information = Starbucks_Information_db.Information
Information.update({},API_Data,upsert=True)
# Out:
# C:\Users\Abraham\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# {'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}

# %%
for i in Information.find():
    returned_Dict = i

returned_Dict["_id"] = str(returned_Dict["_id"])

# %%
returned_Dict
# Out:
# {'_id': '5e197dec3710044fa5c7da91',
#  'Alabama': {'Labor Force': 2181333,
#   'Personal Income Capital': 41079,
#   'Stores': {'76795-96265': {'Ownership Type': 'Licensed',
#     'Street Address': '250 S Colonial Dr',
#     'City': 'Alabaster',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.23},
#    '13210-95453': {'Ownership Type': 'Company Owned',
#     'Street Address': '345 South Colonial Dr',
#     'City': 'Alabaster',
#     'State': 'AL',
#     'Longitude': -86.8,
#     'Latitude': 33.22},
#    '10796-102254': {'Ownership Type': 'Company Owned',
#     'Street Address': '2171 Kent Dairy Rd',
#     'City': 'Alabaster',
#     'State': 'AL',
#     'Longitude': -86.83,
#     'Latitude': 33.21},
#    '10248-100069': {'Ownership Type': 'Company Owned',
#     'Street Address': '1286 Hwy 72 East',
#     'City': 'Athens',
#     'State': 'AL',
#     'Longitude': -86.95,
#     'Latitude': 34.78},
#    '47255-121766': {'Ownership Type': 'Licensed',
#     'Street Address': '300 Dean Rd',
#     'City': 'Auburn',
#     'State': 'AL',
#     'Longitude': -85.46,
#     'Latitude': 32.61},
#    '22803-218127': {'Ownership Type': 'Licensed',
#     'Street Address': 'Magnolia Street',
#     'City': 'Auburn',
#     'State': 'AL',
#     'Longitude': -85.48,
#     'Latitude': 32.61},
#    '78065-105597': {'Ownership Type': 'Licensed',
#     'Street Address': 'Quad Center, 255 Duncan Dr',
#     'City': 'Auburn',
#     'State': 'AL',
#     'Longitude': -85.49,
#     'Latitude': 32.6},
#    '76912-128666': {'Ownership Type': 'Licensed',
#     'Street Address': '4889 Promenade Pkwy',
#     'City': 'Bessemer',
#     'State': 'AL',
#     'Longitude': -86.93,
#     'Latitude': 33.33},
#    '72614-22325': {'Ownership Type': 'Licensed',
#     'Street Address': '4616 Highway 280',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.71,
#     'Latitude': 33.43},
#    '13779-108621': {'Ownership Type': 'Company Owned',
#     'Street Address': '1658 Montclair Rd, Suite 100',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.72,
#     'Latitude': 33.53},
#    '24427-237908': {'Ownership Type': 'Company Owned',
#     'Street Address': '615 18th Street',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.8,
#     'Latitude': 33.51},
#    '18675-189964': {'Ownership Type': 'Licensed',
#     'Street Address': '5900 Messer Airport Way',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.75,
#     'Latitude': 33.56},
#    '11083-104088': {'Ownership Type': 'Company Owned',
#     'Street Address': '231 State Farm Pkwy',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.83,
#     'Latitude': 33.45},
#    '3478-92800': {'Ownership Type': 'Company Owned',
#     'Street Address': '5405 US-280 East',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.67,
#     'Latitude': 33.42},
#    '78059-106248': {'Ownership Type': 'Licensed',
#     'Street Address': '2010 Brookwood Medical Center Drive',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.78,
#     'Latitude': 33.46},
#    '25845-235684': {'Ownership Type': 'Licensed',
#     'Street Address': '1400 University Blvd',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.5},
#    '70067-133044': {'Ownership Type': 'Licensed',
#     'Street Address': '917 13th St',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.5},
#    '23642-225124': {'Ownership Type': 'Company Owned',
#     'Street Address': '308 20th St South, Suite 100',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.8,
#     'Latitude': 33.51},
#    '22706-222686': {'Ownership Type': 'Licensed',
#     'Street Address': '5900 Messer Airport Wy',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.75,
#     'Latitude': 33.56},
#    '75268-97436': {'Ownership Type': 'Licensed',
#     'Street Address': '810 Saint Vincents Dr',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.79,
#     'Latitude': 33.51},
#    '13703-107628': {'Ownership Type': 'Company Owned',
#     'Street Address': '1584 Montgomery Hwy',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.4},
#    '6964-86620': {'Ownership Type': 'Company Owned',
#     'Street Address': '3032 John Hawkins Pkwy',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.37},
#    '8396-28812': {'Ownership Type': 'Company Owned',
#     'Street Address': '1927 11th Avenue South',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.8,
#     'Latitude': 33.5},
#    '72615-22327': {'Ownership Type': 'Licensed',
#     'Street Address': '1654 Gadsden Hwy',
#     'City': 'Birmingham',
#     'State': 'AL',
#     'Longitude': -86.64,
#     'Latitude': 33.6},
#    '17221-169985': {'Ownership Type': 'Company Owned',
#     'Street Address': '1879 Cherokee Avenue, SW, Jubilee Square',
#     'City': 'Cullman',
#     'State': 'AL',
#     'Longitude': -86.84,
#     'Latitude': 34.15},
#    '13211-104121': {'Ownership Type': 'Company Owned',
#     'Street Address': '6830 Highway 90',
#     'City': 'Daphne',
#     'State': 'AL',
#     'Longitude': -87.91,
#     'Latitude': 30.65},
#    '76832-97609': {'Ownership Type': 'Licensed',
#     'Street Address': '2141 Point Mallard Pkwy',
#     'City': 'Decatur',
#     'State': 'AL',
#     'Longitude': -86.96,
#     'Latitude': 34.59},
#    '13704-107959': {'Ownership Type': 'Company Owned',
#     'Street Address': '902 Wimberly Drive SW',
#     'City': 'Decatur',
#     'State': 'AL',
#     'Longitude': -87.0,
#     'Latitude': 34.56},
#    '76742-95745': {'Ownership Type': 'Licensed',
#     'Street Address': '4601 Montgomery Hwy, Suite 300',
#     'City': 'Dothan',
#     'State': 'AL',
#     'Longitude': -85.45,
#     'Latitude': 31.27},
#    '17646-153585': {'Ownership Type': 'Licensed',
#     'Street Address': '1 Harrison Plz',
#     'City': 'Florence',
#     'State': 'AL',
#     'Longitude': -87.68,
#     'Latitude': 34.8},
#    '20271-202065': {'Ownership Type': 'Company Owned',
#     'Street Address': '357 Cox Creek Parkway',
#     'City': 'Florence',
#     'State': 'AL',
#     'Longitude': -87.64,
#     'Latitude': 34.84},
#    '9971-96354': {'Ownership Type': 'Company Owned',
#     'Street Address': '2601 S. McKenzie Road, 900',
#     'City': 'Foley',
#     'State': 'AL',
#     'Longitude': -87.68,
#     'Latitude': 30.38},
#    '76843-111224': {'Ownership Type': 'Licensed',
#     'Street Address': '3489 Lowery Pkwy',
#     'City': 'Fultondale',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.61},
#    '23672-230991': {'Ownership Type': 'Licensed',
#     'Street Address': '1724 W Grand Ave',
#     'City': 'Gadsden',
#     'State': 'AL',
#     'Longitude': -86.08,
#     'Latitude': 33.99},
#    '23630-227625': {'Ownership Type': 'Company Owned',
#     'Street Address': '659 Fieldstown Rd',
#     'City': 'Gardendale',
#     'State': 'AL',
#     'Longitude': -86.82,
#     'Latitude': 33.65},
#    '76584-99835': {'Ownership Type': 'Licensed',
#     'Street Address': '3820 Gulf Shores Pkwy',
#     'City': 'Gulf Shores',
#     'State': 'AL',
#     'Longitude': -87.68,
#     'Latitude': 30.3},
#    '18944-175726': {'Ownership Type': 'Licensed',
#     'Street Address': '531 Brookwood Village',
#     'City': 'Homewood',
#     'State': 'AL',
#     'Longitude': -86.77,
#     'Latitude': 33.47},
#    '24032-228009': {'Ownership Type': 'Company Owned',
#     'Street Address': '5180 Medford Rd, Suite 108',
#     'City': 'Hoover',
#     'State': 'AL',
#     'Longitude': -86.85,
#     'Latitude': 33.36},
#    '6965-85181': {'Ownership Type': 'Company Owned',
#     'Street Address': '4710 Hwy 280 east',
#     'City': 'Hoover',
#     'State': 'AL',
#     'Longitude': -86.7,
#     'Latitude': 33.42},
#    '5108-145307': {'Ownership Type': 'Licensed',
#     'Street Address': '5561 Grove Blvd, Riverchase Galleria',
#     'City': 'Hoover',
#     'State': 'AL',
#     'Longitude': -86.83,
#     'Latitude': 33.4},
#    '28311-249956': {'Ownership Type': 'Company Owned',
#     'Street Address': '3000 Riverchase Galleria, #243, Riverchase Galleria',
#     'City': 'Hoover',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.38},
#    '8488-38759': {'Ownership Type': 'Company Owned',
#     'Street Address': '3000 Riverchase Galleria, 124',
#     'City': 'Hoover',
#     'State': 'AL',
#     'Longitude': -86.81,
#     'Latitude': 33.38},
#    '10127-99686': {'Ownership Type': 'Company Owned',
#     'Street Address': '3421 Memorial Drive NW',
#     'City': 'Huntsville',
#     'State': 'AL',
#     'Longitude': -86.59,
#     'Latitude': 34.77},
#    '72653-48479': {'Ownership Type': 'Licensed',
#     'Street Address': '2750 Carl T Jones Dr SE, 7',
#     'City': 'Huntsville',
#     'State': 'AL',
#     'Longitude': -86.55,
#     'Latitude': 34.68},
#    '9543-97230': {'Ownership Type': 'Company Owned',
#     'Street Address': '800 Airport Rd, Suite A',
#     'City': 'Huntsville',
#     'State': 'AL',
#     'Longitude': -86.57,
#     'Latitude': 34.69},
#    '9507-96863': {'Ownership Type': 'Company Owned',
#     'Street Address': '2003 Whitesburg Drive, Suite D',
#     'City': 'Huntsville',
#     'State': 'AL',
#     'Longitude': -86.58,
#     'Latitude': 34.72},
#    '12493-152666': {'Ownership Type': 'Licensed',
#     'Street Address': '7090 University Dr',
#     'City': 'Huntsville',
#     'State': 'AL',
#     'Longitude': -86.71,
#     'Latitude': 34.75},
#    '72635-32262': {'Ownership Type': 'Licensed',
#     'Street Address': '6275 University Dr',
#     'City': 'Huntsville',
#     'State': 'AL',
#     'Longitude': -86.68,
#     'Latitude': 34.74},
#    '10062-99521': {'Ownership Type': 'Company Owned',
#     'Street Address': '1015 North Memorial Pkwy',
#     'City': 'Huntsville',
#     'State': 'AL',
#     'Longitude': -86.6,
#     'Latitude': 34.74},
#    '11428-104120': {'Ownership Type': 'Company Owned',
#     'Street Address': '7779 Highway 72 West',
#     'City': 'Madison',
#     'State': 'AL',
#     'Longitude': -86.74,
#     'Latitude': 34.75},
#    '48885-260445': {'Ownership Type': 'Licensed',
#     'Street Address': '4579 Wall Triana Hwy',
#     'City': 'Madison',
#     'State': 'AL',
#     'Longitude': -86.75,
#     'Latitude': 34.71},
#    '16910-165028': {'Ownership Type': 'Licensed',
#     'Street Address': '8207 Highway 72 W',
#     'City': 'Madison',
#     'State': 'AL',
#     'Longitude': -86.76,
#     'Latitude': 34.75},
#    '19891-192724': {'Ownership Type': 'Licensed',
#     'Street Address': '5901 USA Dr N',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.18,
#     'Latitude': 30.7},
#    '9970-97273': {'Ownership Type': 'Company Owned',
#     'Street Address': '3255 Airport Blvd, Bel Air Mall',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.12,
#     'Latitude': 30.68},
#    '11673-105401': {'Ownership Type': 'Company Owned',
#     'Street Address': '3494 BEL AIR MALL, G7',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.12,
#     'Latitude': 30.67},
#    '25695-236913': {'Ownership Type': 'Company Owned',
#     'Street Address': '3075 Government Blvd, Suite B100',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.12,
#     'Latitude': 30.65},
#    '72658-64920': {'Ownership Type': 'Licensed',
#     'Street Address': '790 Shillinger Rd S, Shoppes of Midtown',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.23,
#     'Latitude': 30.67},
#    '11324-104129': {'Ownership Type': 'Company Owned',
#     'Street Address': '1510 Government St',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.07,
#     'Latitude': 30.68},
#    '8724-93235': {'Ownership Type': 'Company Owned',
#     'Street Address': '390 Schillinger Road',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.23,
#     'Latitude': 30.68},
#    '10537-96355': {'Ownership Type': 'Company Owned',
#     'Street Address': '1363 Hillcrest Rd',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.19,
#     'Latitude': 30.66},
#    '8581-86640': {'Ownership Type': 'Company Owned',
#     'Street Address': '3901 Airport Blvd',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.14,
#     'Latitude': 30.68},
#    '10538-101306': {'Ownership Type': 'Company Owned',
#     'Street Address': '3451 Spring Hill Ave, Oliver Creek Crossings',
#     'City': 'Mobile',
#     'State': 'AL',
#     'Longitude': -88.13,
#     'Latitude': 30.7},
#    '10772-101748': {'Ownership Type': 'Company Owned',
#     'Street Address': '6501 Atlanta Hwy',
#     'City': 'Montgomery',
#     'State': 'AL',
#     'Longitude': -86.18,
#     'Latitude': 32.38},
#    '21849-215404': {'Ownership Type': 'Licensed',
#     'Street Address': '2576 Berryhill Rd',
#     'City': 'Montgomery',
#     'State': 'AL',
#     'Longitude': -86.16,
#     'Latitude': 32.36},
#    '3426-240988': {'Ownership Type': 'Company Owned',
#     'Street Address': '1601 Eastern Blvd',
#     'City': 'Montgomery',
#     'State': 'AL',
#     'Longitude': -86.22,
#     'Latitude': 32.36},
#    '9809-97244': {'Ownership Type': 'Company Owned',
#     'Street Address': '3110 Zelda Road',
#     'City': 'Montgomery',
#     'State': 'AL',
#     'Longitude': -86.26,
#     'Latitude': 32.35},
#    '2960-85962': {'Ownership Type': 'Company Owned',
#     'Street Address': '6911 East Chase Parkway',
#     'City': 'Montgomery',
#     'State': 'AL',
#     'Longitude': -86.17,
#     'Latitude': 32.36},
#    '10771-102253': {'Ownership Type': 'Company Owned',
#     'Street Address': '7790 Vaughn, Mountain Brook Village',
#     'City': 'Montgomery',
#     'State': 'AL',
#     'Longitude': -86.18,
#     'Latitude': 32.34},
#    '8418-41260': {'Ownership Type': 'Company Owned',
#     'Street Address': '2738 Cahaba Rd',
#     'City': 'Mountain Brook',
#     'State': 'AL',
#     'Longitude': -86.77,
#     'Latitude': 33.48},
#    '76396-80263': {'Ownership Type': 'Licensed',
#     'Street Address': '2640 Enterprise Dr',
#     'City': 'Opelika',
#     'State': 'AL',
#     'Longitude': -85.41,
#     'Latitude': 32.62},
#    '25201-233569': {'Ownership Type': 'Licensed',
#     'Street Address': '2460 Enterprise Dr',
#     'City': 'Opelika',
#     'State': 'AL',
#     'Longitude': -85.37,
#     'Latitude': 32.64},
#    '9544-97240': {'Ownership Type': 'Company Owned',
#     'Street Address': '2056 Interstate Drive',
#     'City': 'Opelika',
#     'State': 'AL',
#     'Longitude': -85.4,
#     'Latitude': 32.62},
#    '24727-236464': {'Ownership Type': 'Company Owned',
#     'Street Address': '25773 Perdido Beach Blvd',
#     'City': 'Orange Beach',
#     'State': 'AL',
#     'Longitude': -87.59,
#     'Latitude': 30.27},
#    '76606-101463': {'Ownership Type': 'Licensed',
#     'Street Address': '400 Oxford Exchange Blvd',
#     'City': 'Oxford',
#     'State': 'AL',
#     'Longitude': -85.78,
#     'Latitude': 33.61},
#    '9738-97528': {'Ownership Type': 'Company Owned',
#     'Street Address': '1011 Hwy 21 South',
#     'City': 'Oxford',
#     'State': 'AL',
#     'Longitude': -85.83,
#     'Latitude': 33.61},
#    '20585-202066': {'Ownership Type': 'Company Owned',
#     'Street Address': '2588 Cobbs Ford Road',
#     'City': 'Prattville',
#     'State': 'AL',
#     'Longitude': -86.39,
#     'Latitude': 32.46},
#    '76796-108570': {'Ownership Type': 'Licensed',
#     'Street Address': '2754 Legends Pkwy',
#     'City': 'Prattville',
#     'State': 'AL',
#     'Longitude': -86.43,
#     'Latitude': 32.47},
#    '10249-96359': {'Ownership Type': 'Company Owned',
#     'Street Address': '30350 State Hwy 181, Suite A',
#     'City': 'Spanish Fort',
#     'State': 'AL',
#     'Longitude': -87.85,
#     'Latitude': 30.67},
#    '3453-93234': {'Ownership Type': 'Company Owned',
#     'Street Address': '1420 Gadsden Hwy, BAMA Dining Services/Starbucks Coffee',
#     'City': 'Trussville',
#     'State': 'AL',
#     'Longitude': -86.65,
#     'Latitude': 33.6},
#    '72121-3608': {'Ownership Type': 'Licensed',
#     'Street Address': '1000 McCorvey Dr., UoA-Ferguson Center',
#     'City': 'Tuscaloosa',
#     'State': 'AL',
#     'Longitude': -87.55,
#     'Latitude': 33.21},
#    '13482-94577': {'Ownership Type': 'Company Owned',
#     'Street Address': '1800 McFarland Blvd, Suite 600',
#     'City': 'Tuscaloosa',
#     'State': 'AL',
#     'Longitude': -87.53,
#     'Latitude': 33.2},
#    '72668-65003': {'Ownership Type': 'Licensed',
#     'Street Address': '1901 13th Ave E',
#     'City': 'Tuscaloosa',
#     'State': 'AL',
#     'Longitude': -87.51,
#     'Latitude': 33.2},
#    '48066-207044': {'Ownership Type': 'Licensed',
#     'Street Address': '838 Paul W Bryant Drive',
#     'City': 'Tuscaloosa',
#     'State': 'AL',
#     'Longitude': -87.55,
#     'Latitude': 33.21},
#    '9587-97243': {'Ownership Type': 'Company Owned',
#     'Street Address': '3130 Cahaba Heights Rd',
#     'City': 'Vestavia Hills',
#     'State': 'AL',
#     'Longitude': -86.74,
#     'Latitude': 33.46},
#    '8560-79440': {'Ownership Type': 'Company Owned',
#     'Street Address': '700 Montgomery Hwy, Suite 100',
#     'City': 'Vestavia Hills',
#     'State': 'AL',
#     'Longitude': -86.79,
#     'Latitude': 33.45}}},
#  'Alaska': {'Labor Force': 358859,
#   'Personal Income Capital': 57527,
#   'Stores': {'3513-125945': {'Ownership Type': 'Licensed',
#     'Street Address': '5600 Debarr Rd Ste 9',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.78,
#     'Latitude': 61.21},
#    '74352-84449': {'Ownership Type': 'Licensed',
#     'Street Address': '1725 Abbott Rd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.84,
#     'Latitude': 61.14},
#    '12449-152385': {'Ownership Type': 'Licensed',
#     'Street Address': '1501 Huffman Rd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.85,
#     'Latitude': 61.11},
#    '24936-233524': {'Ownership Type': 'Company Owned',
#     'Street Address': '320 W. 100th Ave, 100, Southgate Shopping Ctr - Anchorage',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.89,
#     'Latitude': 61.13},
#    '8973-85630': {'Ownership Type': 'Company Owned',
#     'Street Address': '1005 E Dimond Blvd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.86,
#     'Latitude': 61.14},
#    '72788-84447': {'Ownership Type': 'Licensed',
#     'Street Address': '1000 E Northern Lights Blvd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.87,
#     'Latitude': 61.19},
#    '79549-106150': {'Ownership Type': 'Licensed',
#     'Street Address': '3101 PENLAND PKWY.',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.82,
#     'Latitude': 61.22},
#    '75988-107245': {'Ownership Type': 'Licensed',
#     'Street Address': 'HMSHost, 500 West International Airport',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.98,
#     'Latitude': 61.18},
#    '11426-99254': {'Ownership Type': 'Company Owned',
#     'Street Address': '110 W. Tudor Rd, E',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.88,
#     'Latitude': 61.18},
#    '20349-108249': {'Ownership Type': 'Licensed',
#     'Street Address': '7701 Debarr Road',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.74,
#     'Latitude': 61.21},
#    '74266-52019': {'Ownership Type': 'Licensed',
#     'Street Address': '7731 E Northern Lights Blvd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.74,
#     'Latitude': 61.2},
#    '72727-61659': {'Ownership Type': 'Licensed',
#     'Street Address': '2300 Abbott Road',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.84,
#     'Latitude': 61.14},
#    '76943-129964': {'Ownership Type': 'Licensed',
#     'Street Address': '1200 N Muldoon Rd, Suite F',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.74,
#     'Latitude': 61.23},
#    '72784-33081': {'Ownership Type': 'Licensed',
#     'Street Address': '2000 W Dimond Blvd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.92,
#     'Latitude': 61.14},
#    '9622-85633': {'Ownership Type': 'Company Owned',
#     'Street Address': '2421 East Tudor Road, Suite 8',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.84,
#     'Latitude': 61.18},
#    '75323-100264': {'Ownership Type': 'Licensed',
#     'Street Address': 'Bldg 5800 Westover Avenue',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.75,
#     'Latitude': 61.23},
#    '79664-81037': {'Ownership Type': 'Licensed',
#     'Street Address': '4000 W Dimond Blvd, Anchorage Fifth Avenue',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.96,
#     'Latitude': 61.14},
#    '28191-249962': {'Ownership Type': 'Company Owned',
#     'Street Address': '320 West 5th Avenue, #D50A',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.89,
#     'Latitude': 61.22},
#    '3774-145044': {'Ownership Type': 'Licensed',
#     'Street Address': '150 W 100th Ave Suite A',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.88,
#     'Latitude': 61.13},
#    '28028-249124': {'Ownership Type': 'Licensed',
#     'Street Address': '5000 West International Rd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.95,
#     'Latitude': 61.15},
#    '75697-94324': {'Ownership Type': 'Licensed',
#     'Street Address': '5000 W Intl Airport Rd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.98,
#     'Latitude': 61.17},
#    '74430-51979': {'Ownership Type': 'Licensed',
#     'Street Address': '1650 W Northern Lights Blvd',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.92,
#     'Latitude': 61.19},
#    '17941-159568': {'Ownership Type': 'Company Owned',
#     'Street Address': '1142 N. Muldoon Road, 110, Anchorage 5th Ave Mall',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.74,
#     'Latitude': 61.23},
#    '19819-178265': {'Ownership Type': 'Company Owned',
#     'Street Address': '320 West 5th Avenue, 224',
#     'City': 'Anchorage',
#     'State': 'AK',
#     'Longitude': -149.89,
#     'Latitude': 61.22},
#    '74265-64199': {'Ownership Type': 'Licensed',
#     'Street Address': '11409 Business Blvd',
#     'City': 'Eagle River',
#     'State': 'AK',
#     'Longitude': -149.57,
#     'Latitude': 61.32},
#    '10126-97747': {'Ownership Type': 'Company Owned',
#     'Street Address': '16707 Coronado Road, 100',
#     'City': 'Eagle River',
#     'State': 'AK',
#     'Longitude': -149.57,
#     'Latitude': 61.33},
#    '72772-78880': {'Ownership Type': 'Licensed',
#     'Street Address': '13401 Old Glenn Hwy',
#     'City': 'Eagle River',
#     'State': 'AK',
#     'Longitude': -149.55,
#     'Latitude': 61.35},
#    '79719-100712': {'Ownership Type': 'Licensed',
#     'Street Address': '3627 Airport Way (405R)',
#     'City': 'Fairbanks',
#     'State': 'AK',
#     'Longitude': -147.81,
#     'Latitude': 64.84},
#    '74452-94707': {'Ownership Type': 'Licensed',
#     'Street Address': '30 College Rd',
#     'City': 'Fairbanks',
#     'State': 'AK',
#     'Longitude': -147.7,
#     'Latitude': 64.85},
#    '72709-33079': {'Ownership Type': 'Licensed',
#     'Street Address': '3755 Airport Way',
#     'City': 'Fairbanks',
#     'State': 'AK',
#     'Longitude': -147.82,
#     'Latitude': 64.84},
#    '27150-246609': {'Ownership Type': 'Licensed',
#     'Street Address': '6450 Airport Way',
#     'City': 'Fairbanks',
#     'State': 'AK',
#     'Longitude': -147.87,
#     'Latitude': 64.82},
#    '72975-95761': {'Ownership Type': 'Licensed',
#     'Street Address': '930 Old Steese Hwy, A',
#     'City': 'Fairbanks',
#     'State': 'AK',
#     'Longitude': -147.69,
#     'Latitude': 64.85},
#    '75471-106357': {'Ownership Type': 'Licensed',
#     'Street Address': 'Frontier Theater, Building 2',
#     'City': 'Fort Richardson',
#     'State': 'AK',
#     'Longitude': -149.68,
#     'Latitude': 61.26},
#    '70386-135644': {'Ownership Type': 'Licensed',
#     'Street Address': 'Bldg # 3703B',
#     'City': 'Fort Wainwright',
#     'State': 'AK',
#     'Longitude': -147.65,
#     'Latitude': 64.83},
#    '74917-98110': {'Ownership Type': 'Licensed',
#     'Street Address': '90 Sterling Hwy',
#     'City': 'Homer',
#     'State': 'AK',
#     'Longitude': -151.54,
#     'Latitude': 59.64},
#    '74283-69901': {'Ownership Type': 'Licensed',
#     'Street Address': '303 Vintage Blvd',
#     'City': 'Juneau',
#     'State': 'AK',
#     'Longitude': -134.55,
#     'Latitude': 58.36},
#    '79324-94693': {'Ownership Type': 'Licensed',
#     'Street Address': '8181 Old Glacier Hwy',
#     'City': 'Juneau',
#     'State': 'AK',
#     'Longitude': -134.56,
#     'Latitude': 58.36},
#    '74640-93401': {'Ownership Type': 'Licensed',
#     'Street Address': '2417 Tongass Ave',
#     'City': 'Ketchikan',
#     'State': 'AK',
#     'Longitude': -131.67,
#     'Latitude': 55.35},
#    '74474-94708': {'Ownership Type': 'Licensed',
#     'Street Address': '2685 Mill Bay Rd',
#     'City': 'Kodiak',
#     'State': 'AK',
#     'Longitude': -152.37,
#     'Latitude': 57.81},
#    '25843-94709': {'Ownership Type': 'Licensed',
#     'Street Address': '301 N Santa Claus Lane',
#     'City': 'North Pole',
#     'State': 'AK',
#     'Longitude': -147.35,
#     'Latitude': 64.76},
#    '15313-159926': {'Ownership Type': 'Licensed',
#     'Street Address': '664 W Evergreen Ave',
#     'City': 'Palmer',
#     'State': 'AK',
#     'Longitude': -149.13,
#     'Latitude': 61.6},
#    '72980-94694': {'Ownership Type': 'Licensed',
#     'Street Address': '650 N Cobb St',
#     'City': 'Palmer',
#     'State': 'AK',
#     'Longitude': -149.12,
#     'Latitude': 61.6},
#    '74706-97007': {'Ownership Type': 'Licensed',
#     'Street Address': '1907 Seward Hwy',
#     'City': 'Seward',
#     'State': 'AK',
#     'Longitude': -149.43,
#     'Latitude': 60.13},
#    '72946-94692': {'Ownership Type': 'Licensed',
#     'Street Address': '43843 Sterling Hwy',
#     'City': 'Soldotna',
#     'State': 'AK',
#     'Longitude': -151.05,
#     'Latitude': 60.49},
#    '74695-94706': {'Ownership Type': 'Licensed',
#     'Street Address': '44282 Sterling Hwy S',
#     'City': 'Soldotna',
#     'State': 'AK',
#     'Longitude': -151.07,
#     'Latitude': 60.48},
#    '17912-136436': {'Ownership Type': 'Company Owned',
#     'Street Address': '1771 East Parks Hwy, Unit #4',
#     'City': 'Wasilla',
#     'State': 'AK',
#     'Longitude': -149.41,
#     'Latitude': 61.58},
#    '4146-104969': {'Ownership Type': 'Licensed',
#     'Street Address': '595 E Parks Hwy',
#     'City': 'Wasilla',
#     'State': 'AK',
#     'Longitude': -149.44,
#     'Latitude': 61.58},
#    '76916-131305': {'Ownership Type': 'Licensed',
#     'Street Address': '1801 E Parks Hwy',
#     'City': 'Wasilla',
#     'State': 'AK',
#     'Longitude': -149.41,
#     'Latitude': 61.58},
#    '72773-82040': {'Ownership Type': 'Licensed',
#     'Street Address': '1501 East Parks Highway',
#     'City': 'Wasilla',
#     'State': 'AK',
#     'Longitude': -149.41,
#     'Latitude': 61.58}}},
#  'Arizona': {'Labor Force': 3368789,
#   'Personal Income Capital': 43128,
#   'Stores': {'21989-106025': {'Ownership Type': 'Licensed',
#     'Street Address': '39508 N. Daisy Mountain Drive',
#     'City': 'Anthem',
#     'State': 'AZ',
#     'Longitude': -112.13,
#     'Latitude': 33.84},
#    '6581-67540': {'Ownership Type': 'Company Owned',
#     'Street Address': '3640 W. Anthem Way',
#     'City': 'Anthem',
#     'State': 'AZ',
#     'Longitude': -112.14,
#     'Latitude': 33.87},
#    '14177-106635': {'Ownership Type': 'Company Owned',
#     'Street Address': '39504 N. Daisy Mountain Drive, #118',
#     'City': 'Anthem',
#     'State': 'AZ',
#     'Longitude': -112.13,
#     'Latitude': 33.84},
#    '3765-148824': {'Ownership Type': 'Licensed',
#     'Street Address': '185 W Apache Tr',
#     'City': 'Apache Junction',
#     'State': 'AZ',
#     'Longitude': -111.55,
#     'Latitude': 33.41},
#    '9862-97880': {'Ownership Type': 'Company Owned',
#     'Street Address': '2580 W. Apache Trail',
#     'City': 'Apache Junction',
#     'State': 'AZ',
#     'Longitude': -111.57,
#     'Latitude': 33.42},
#    '47792-257948': {'Ownership Type': 'Licensed',
#     'Street Address': '1575 N Dysart Rd, Gateway Pavillions',
#     'City': 'Avondale',
#     'State': 'AZ',
#     'Longitude': -112.34,
#     'Latitude': 33.46},
#    '6779-78100': {'Ownership Type': 'Company Owned',
#     'Street Address': '10030 W  McDowell Rd, Ste 160',
#     'City': 'Avondale',
#     'State': 'AZ',
#     'Longitude': -112.28,
#     'Latitude': 33.46},
#    '9415-96478': {'Ownership Type': 'Company Owned',
#     'Street Address': '11435 W. Buckeye Road, A101, Westwind Plaza',
#     'City': 'Avondale',
#     'State': 'AZ',
#     'Longitude': -112.31,
#     'Latitude': 33.43},
#    '6690-75361': {'Ownership Type': 'Company Owned',
#     'Street Address': '10585 W. Indian School Rd',
#     'City': 'Avondale',
#     'State': 'AZ',
#     'Longitude': -112.29,
#     'Latitude': 33.49},
#    '3923-145470': {'Ownership Type': 'Licensed',
#     'Street Address': '599 W 4th St',
#     'City': 'Benson',
#     'State': 'AZ',
#     'Longitude': -110.31,
#     'Latitude': 31.97},
#    '79633-111085': {'Ownership Type': 'Licensed',
#     'Street Address': '101 NACO HIGHWAY',
#     'City': 'Bisbee',
#     'State': 'AZ',
#     'Longitude': -109.92,
#     'Latitude': 31.4},
#    '21316-211384': {'Ownership Type': 'Licensed',
#     'Street Address': '1300 S. Watson Rd.',
#     'City': 'Buckeye',
#     'State': 'AZ',
#     'Longitude': -112.56,
#     'Latitude': 33.43},
#    '74292-74769': {'Ownership Type': 'Licensed',
#     'Street Address': '1751 Highway 95',
#     'City': 'Bullhead City',
#     'State': 'AZ',
#     'Longitude': -114.59,
#     'Latitude': 35.12},
#    '76879-121628': {'Ownership Type': 'Licensed',
#     'Street Address': '3699 Hwy 95, Kokopelli Plaza',
#     'City': 'Bullhead City',
#     'State': 'AZ',
#     'Longitude': -114.59,
#     'Latitude': 35.05},
#    '8105-95016': {'Ownership Type': 'Company Owned',
#     'Street Address': '1620 W. Highway 260, #A',
#     'City': 'Camp Verde',
#     'State': 'AZ',
#     'Longitude': -111.88,
#     'Latitude': 34.58},
#    '73896-103689': {'Ownership Type': 'Licensed',
#     'Street Address': '650 Finney Flat Rd',
#     'City': 'Camp Verde',
#     'State': 'AZ',
#     'Longitude': -111.86,
#     'Latitude': 34.57},
#    '47139-256164': {'Ownership Type': 'Licensed',
#     'Street Address': '36889 TOM DARLINGTON',
#     'City': 'CAREFREE',
#     'State': 'AZ',
#     'Longitude': -111.92,
#     'Latitude': 33.82},
#    '74398-83385': {'Ownership Type': 'Licensed',
#     'Street Address': '1637 N Trekel Rd',
#     'City': 'Casa Grande',
#     'State': 'AZ',
#     'Longitude': -111.74,
#     'Latitude': 32.9},
#    '11217-103791': {'Ownership Type': 'Company Owned',
#     'Street Address': '1485 E. Florence Blvd., #6',
#     'City': 'Casa Grande',
#     'State': 'AZ',
#     'Longitude': -111.72,
#     'Latitude': 32.88},
#    '73946-106028': {'Ownership Type': 'Licensed',
#     'Street Address': '2858 North Pinal Avenue',
#     'City': 'Casa Grande',
#     'State': 'AZ',
#     'Longitude': -111.76,
#     'Latitude': 32.93},
#    '73847-106042': {'Ownership Type': 'Licensed',
#     'Street Address': '4815 E. Carfree highway',
#     'City': 'Cave Creek',
#     'State': 'AZ',
#     'Longitude': -111.98,
#     'Latitude': 33.8},
#    '6582-243618': {'Ownership Type': 'Company Owned',
#     'Street Address': '5310 E Carefree Hwy',
#     'City': 'Cave Creek',
#     'State': 'AZ',
#     'Longitude': -111.97,
#     'Latitude': 33.8},
#    '22006-106706': {'Ownership Type': 'Licensed',
#     'Street Address': '29455 N Cave Creek Rd',
#     'City': 'Cave Creek',
#     'State': 'AZ',
#     'Longitude': -111.99,
#     'Latitude': 33.75},
#    '48890-245841': {'Ownership Type': 'Licensed',
#     'Street Address': 'Gilbert & Ocotillo',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.8,
#     'Latitude': 33.22},
#    '11984-104952': {'Ownership Type': 'Company Owned',
#     'Street Address': '2885 W. Ray Road, #1',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.89,
#     'Latitude': 33.32},
#    '5907-35120': {'Ownership Type': 'Company Owned',
#     'Street Address': '985 West Elliot Road, 7, The Village at Chandler Fashion Center',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.86,
#     'Latitude': 33.35},
#    '5974-40479': {'Ownership Type': 'Company Owned',
#     'Street Address': '3161 W Chandler Blvd',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.9,
#     'Latitude': 33.3},
#    '29379-251913': {'Ownership Type': 'Company Owned',
#     'Street Address': '4095 S. Gilbert Road, Suite 1',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.25},
#    '17721-165444': {'Ownership Type': 'Company Owned',
#     'Street Address': '3731 S Arizona Avenue, Chandler Fashion Center',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.84,
#     'Latitude': 33.25},
#    '28207-249841': {'Ownership Type': 'Company Owned',
#     'Street Address': '3111 W. Chandler BLVD., #2402',
#     'City': 'CHANDLER',
#     'State': 'AZ',
#     'Longitude': -111.9,
#     'Latitude': 33.31},
#    '74493-96793': {'Ownership Type': 'Licensed',
#     'Street Address': '4970 S Alma School Rd',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.86,
#     'Latitude': 33.23},
#    '6722-71281': {'Ownership Type': 'Company Owned',
#     'Street Address': '6140 West Chandler Blvd, #8',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.95,
#     'Latitude': 33.31},
#    '11889-105156': {'Ownership Type': 'Company Owned',
#     'Street Address': '4970 S. Gilbert Road, #3',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.23},
#    '73701-106036': {'Ownership Type': 'Licensed',
#     'Street Address': '985 E. Riggs Road',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.73,
#     'Latitude': 33.22},
#    '74805-98888': {'Ownership Type': 'Licensed',
#     'Street Address': '1060 E Ray Rd',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.82,
#     'Latitude': 33.32},
#    '5448-238024': {'Ownership Type': 'Company Owned',
#     'Street Address': '350 S. Dobson Road',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.88,
#     'Latitude': 33.3},
#    '20381-204925': {'Ownership Type': 'Company Owned',
#     'Street Address': '1245 W. CHANDLER BLVD, #1',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.86,
#     'Latitude': 33.31},
#    '20336-204609': {'Ownership Type': 'Licensed',
#     'Street Address': '3425 W Frye Rd, Copper Point',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.9,
#     'Latitude': 33.3},
#    '6635-63359': {'Ownership Type': 'Company Owned',
#     'Street Address': '4030 W. Ray Road, #3',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.91,
#     'Latitude': 33.32},
#    '8975-95098': {'Ownership Type': 'Company Owned',
#     'Street Address': '1395 S. Arizona Avenue, #1',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.84,
#     'Latitude': 33.29},
#    '15775-153907': {'Ownership Type': 'Licensed',
#     'Street Address': '3777 S Arizona Ave, The Falls at Ocotillo',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.84,
#     'Latitude': 33.25},
#    '6560-64619': {'Ownership Type': 'Company Owned',
#     'Street Address': '1085 W Queen Creek Rd, B',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.86,
#     'Latitude': 33.26},
#    '72536-102068': {'Ownership Type': 'Licensed',
#     'Street Address': '4940 S Gilbert Rd',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.23},
#    '22030-214184': {'Ownership Type': 'Licensed',
#     'Street Address': '2010 S  Alma School Rd',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.86,
#     'Latitude': 33.28},
#    '73578-74774': {'Ownership Type': 'Licensed',
#     'Street Address': '2935 E Riggs Road',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.22},
#    '79796-111048': {'Ownership Type': 'Licensed',
#     'Street Address': '1159 W Chandler Blvd, Chandler Pavilions',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.86,
#     'Latitude': 33.3},
#    '5898-35199': {'Ownership Type': 'Company Owned',
#     'Street Address': '885 N. 54th Street, 1, Corona Del Sol Plaza',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.97,
#     'Latitude': 33.32},
#    '15746-160304': {'Ownership Type': 'Company Owned',
#     'Street Address': '4985 W. Ray Rd',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.93,
#     'Latitude': 33.32},
#    '22183-214187': {'Ownership Type': 'Licensed',
#     'Street Address': '4976 Premium Outlets Wy K1',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.93,
#     'Latitude': 33.3},
#    '6885-82582': {'Ownership Type': 'Company Owned',
#     'Street Address': '2050 N. Dobson Road, Suite 5',
#     'City': 'Chandler',
#     'State': 'AZ',
#     'Longitude': -111.88,
#     'Latitude': 33.34},
#    '74416-88963': {'Ownership Type': 'Licensed',
#     'Street Address': '1031 N US Hwy 89',
#     'City': 'Chino Valley',
#     'State': 'AZ',
#     'Longitude': -112.45,
#     'Latitude': 34.76},
#    '70318-136608': {'Ownership Type': 'Licensed',
#     'Street Address': '1449 N Arizona Blvd',
#     'City': 'Coolidge',
#     'State': 'AZ',
#     'Longitude': -111.52,
#     'Latitude': 32.99},
#    '74411-82504': {'Ownership Type': 'Licensed',
#     'Street Address': '1635 Cottonwood St',
#     'City': 'Cottonwood',
#     'State': 'AZ',
#     'Longitude': -112.01,
#     'Latitude': 34.73},
#    '79536-101003': {'Ownership Type': 'Licensed',
#     'Street Address': '1500 East Cedar Ave',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.62,
#     'Latitude': 35.22},
#    '25697-103428': {'Ownership Type': 'Licensed',
#     'Street Address': '2700 S Woodlands Village Blvd',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.67,
#     'Latitude': 35.18},
#    '70023-117805': {'Ownership Type': 'Licensed',
#     'Street Address': 'Building 30',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.66,
#     'Latitude': 35.19},
#    '17806-185724': {'Ownership Type': 'Licensed',
#     'Street Address': '300 E McConnell Dr',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.65,
#     'Latitude': 35.18},
#    '74227-59039': {'Ownership Type': 'Licensed',
#     'Street Address': '1201 S Plaza Way',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.66,
#     'Latitude': 35.19},
#    '9624-96090': {'Ownership Type': 'Company Owned',
#     'Street Address': '1307 S. Milton Road',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.66,
#     'Latitude': 35.19},
#    '79552-96791': {'Ownership Type': 'Licensed',
#     'Street Address': '4910 N US-89',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.58,
#     'Latitude': 35.23},
#    '5988-211704': {'Ownership Type': 'Company Owned',
#     'Street Address': '1688 East Route 66',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.63,
#     'Latitude': 35.2},
#    '76430-97574': {'Ownership Type': 'Licensed',
#     'Street Address': '1650 S Milton Rd',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.66,
#     'Latitude': 35.18},
#    '23523-230691': {'Ownership Type': 'Licensed',
#     'Street Address': '201 N Switzer Canyon Dr',
#     'City': 'Flagstaff',
#     'State': 'AZ',
#     'Longitude': -111.63,
#     'Latitude': 35.19},
#    '79659-107241': {'Ownership Type': 'Licensed',
#     'Street Address': '3325 North Hunt Highway',
#     'City': 'Florence',
#     'State': 'AZ',
#     'Longitude': -111.49,
#     'Latitude': 33.06},
#    '78098-106795': {'Ownership Type': 'Licensed',
#     'Street Address': 'Smith Ave & Hatfield St, Bldg 52030',
#     'City': 'Fort Huachuca',
#     'State': 'AZ',
#     'Longitude': -110.36,
#     'Latitude': 31.55},
#    '25967-242726': {'Ownership Type': 'Licensed',
#     'Street Address': '4747 Highway 95',
#     'City': 'Fort Mohave',
#     'State': 'AZ',
#     'Longitude': -114.6,
#     'Latitude': 35.02},
#    '74975-101172': {'Ownership Type': 'Licensed',
#     'Street Address': '4823 S Hwy 95',
#     'City': 'Fort Mohave',
#     'State': 'AZ',
#     'Longitude': -114.6,
#     'Latitude': 35.02},
#    '5586-1312': {'Ownership Type': 'Company Owned',
#     'Street Address': '16425 E. Palisades Blvd., Suite 101',
#     'City': 'Fountain Hills',
#     'State': 'AZ',
#     'Longitude': -111.73,
#     'Latitude': 33.61},
#    '74539-65039': {'Ownership Type': 'Licensed',
#     'Street Address': '13733 Fountain Hills Blvd',
#     'City': 'Fountain Hills',
#     'State': 'AZ',
#     'Longitude': -111.73,
#     'Latitude': 33.61},
#    '20344-204610': {'Ownership Type': 'Licensed',
#     'Street Address': '16825 E. Shea Boulevard',
#     'City': 'Fountain Hills',
#     'State': 'AZ',
#     'Longitude': -111.72,
#     'Latitude': 33.57},
#    '76302-96624': {'Ownership Type': 'Licensed',
#     'Street Address': '3931 S Gilbert Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.28},
#    '7137-150410': {'Ownership Type': 'Licensed',
#     'Street Address': '6470 S Higley Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.72,
#     'Latitude': 33.29},
#    '19282-181688': {'Ownership Type': 'Company Owned',
#     'Street Address': '2882 South San Tan Village',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.74,
#     'Latitude': 33.3},
#    '22387-167244': {'Ownership Type': 'Licensed',
#     'Street Address': '87 E Williams Field Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.3},
#    '73540-53499': {'Ownership Type': 'Licensed',
#     'Street Address': '861 E Warner',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.81,
#     'Latitude': 33.34},
#    '25972-237346': {'Ownership Type': 'Licensed',
#     'Street Address': '855 W Warner Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.81,
#     'Latitude': 33.33},
#    '23573-230686': {'Ownership Type': 'Licensed',
#     'Street Address': '3261 E Pecos Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.72,
#     'Latitude': 33.29},
#    '70372-127124': {'Ownership Type': 'Licensed',
#     'Street Address': 'SR-202 Loop & William Fields Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.75,
#     'Latitude': 33.33},
#    '19229-199644': {'Ownership Type': 'Licensed',
#     'Street Address': '1845 E Baseline Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.38},
#    '74792-94835': {'Ownership Type': 'Licensed',
#     'Street Address': '5137 E Baseline Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.72,
#     'Latitude': 33.38},
#    '5966-42259': {'Ownership Type': 'Company Owned',
#     'Street Address': '1505 E. Warner Road, 100',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.76,
#     'Latitude': 33.33},
#    '9413-95026': {'Ownership Type': 'Company Owned',
#     'Street Address': '3765 S. Gilbert Rd, #107, SanTan Village',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.79,
#     'Latitude': 33.28},
#    '28560-250158': {'Ownership Type': 'Company Owned',
#     'Street Address': '2200 E. Williamsfield Rd., Spc. 640',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.74,
#     'Latitude': 33.31},
#    '74237-64179': {'Ownership Type': 'Licensed',
#     'Street Address': '90 S Val Vista Dr',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.76,
#     'Latitude': 33.35},
#    '73601-83370': {'Ownership Type': 'Licensed',
#     'Street Address': '8454 S Power Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.69,
#     'Latitude': 33.27},
#    '73849-118684': {'Ownership Type': 'Licensed',
#     'Street Address': '99 S Higley Rd',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.72,
#     'Latitude': 33.35},
#    '5377-239765': {'Ownership Type': 'Company Owned',
#     'Street Address': '830 W Warner Rd, Suite 104, Arrowhead Towne Center',
#     'City': 'Gilbert',
#     'State': 'AZ',
#     'Longitude': -111.81,
#     'Latitude': 33.34},
#    '28192-249957': {'Ownership Type': 'Company Owned',
#     'Street Address': '7700 Arrowhead Towne Ctr., #1223',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.23,
#     'Latitude': 33.64},
#    '76853-111232': {'Ownership Type': 'Licensed',
#     'Street Address': '10404 N 43rd Ave',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.15,
#     'Latitude': 33.58},
#    '10259-99925': {'Ownership Type': 'Company Owned',
#     'Street Address': '6649 W. Peoria Avenue, 1, Retail Shops at Walmart',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.2,
#     'Latitude': 33.58},
#    '6894-84202': {'Ownership Type': 'Company Owned',
#     'Street Address': '8251 W. Union Hills Drive, #100, Arrowhead Ranch Plaza',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.23,
#     'Latitude': 33.65},
#    '6874-85694': {'Ownership Type': 'Company Owned',
#     'Street Address': '18555 N. 59th Avenue, 131',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.19,
#     'Latitude': 33.65},
#    '75378-103975': {'Ownership Type': 'Licensed',
#     'Street Address': '4701 W. Thunderbird Road',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.16,
#     'Latitude': 33.61},
#    '74450-94951': {'Ownership Type': 'Licensed',
#     'Street Address': '20205 N 67th Ave, 100',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.2,
#     'Latitude': 33.67},
#    '20216-195245': {'Ownership Type': 'Licensed',
#     'Street Address': '3800 W Happy Valley Rd #107, Luke AFB',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.14,
#     'Latitude': 33.71},
#    '72123-3569': {'Ownership Type': 'Licensed',
#     'Street Address': '7123 N. 138th Ave., Building 1540',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.36,
#     'Latitude': 33.54},
#    '25584-240129': {'Ownership Type': 'Company Owned',
#     'Street Address': '7510 W. Aspera Blvd. Suite #101',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.22,
#     'Latitude': 33.67},
#    '5376-1128': {'Ownership Type': 'Company Owned',
#     'Street Address': '20249 N. 67th Ave., # B',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.2,
#     'Latitude': 33.67},
#    '73348-24048': {'Ownership Type': 'Licensed',
#     'Street Address': '5040 W. Cactus',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.17,
#     'Latitude': 33.6},
#    '79705-101002': {'Ownership Type': 'Licensed',
#     'Street Address': '5860 West Thunderbird',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.18,
#     'Latitude': 33.61},
#    '5465-1129': {'Ownership Type': 'Company Owned',
#     'Street Address': '5894 W. Thunderbird Rd., Suite #2',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.19,
#     'Latitude': 33.61},
#    '5500-249087': {'Ownership Type': 'Company Owned',
#     'Street Address': '7700 Arrowhead Town Center, K107',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.23,
#     'Latitude': 33.64},
#    '73971-138188': {'Ownership Type': 'Licensed',
#     'Street Address': '20220 N 59th Ave',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.19,
#     'Latitude': 33.67},
#    '5036-106034': {'Ownership Type': 'Licensed',
#     'Street Address': '6611 W Bell Rd',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.15,
#     'Latitude': 33.64},
#    '6539-155146': {'Ownership Type': 'Company Owned',
#     'Street Address': '3860 W. Happy Valley Road, 100',
#     'City': 'Glendale',
#     'State': 'AZ',
#     'Longitude': -112.14,
#     'Latitude': 33.71},
#    '27678-241729': {'Ownership Type': 'Licensed',
#     'Street Address': '5310 S Superstition Mountain Drive',
#     'City': 'Gold Canyon',
#     'State': 'AZ',
#     'Longitude': -111.47,
#     'Latitude': 33.37},
#    '8188-150412': {'Ownership Type': 'Licensed',
#     'Street Address': '16380 W Yuma Rd',
#     'City': 'Goodyear',
#     'State': 'AZ',
#     'Longitude': -112.41,
#     'Latitude': 33.44},
#    '76968-129328': {'Ownership Type': 'Licensed',
#     'Street Address': '995 South Cotton Lane',
#     'City': 'Goodyear',
#     'State': 'AZ',
#     'Longitude': -112.4,
#     'Latitude': 33.46},
#    '74446-86460': {'Ownership Type': 'Licensed',
#     'Street Address': '440 N Estrella Pkwy, Cornerstone North',
#     'City': 'Goodyear',
#     'State': 'AZ',
#     'Longitude': -112.39,
#     'Latitude': 33.45},
#    '11890-95688': {'Ownership Type': 'Company Owned',
#     'Street Address': '1690 N. Dysart Road',
#     'City': 'Goodyear',
#     'State': 'AZ',
#     'Longitude': -112.34,
#     'Latitude': 33.47},
#    '74198-34460': {'Ownership Type': 'Licensed',
#     'Street Address': '14175 W Indian Sch R, Palm Valley Pavillion',
#     'City': 'Goodyear',
#     'State': 'AZ',
#     'Longitude': -112.36,
#     'Latitude': 33.49},
#    '5923-37479': {'Ownership Type': 'Company Owned',
#     'Street Address': '1375 North Litchfield Road, 100',
#     'City': 'GOODYEAR',
#     'State': 'AZ',
#     'Longitude': -112.36,
#     'Latitude': 33.46},
# ...
#     'City': 'Milwaukee',
#     'State': 'WI',
#     'Longitude': -87.9,
#     'Latitude': 42.95},
#    '2512-31899': {'Ownership Type': 'Company Owned',
#     'Street Address': '326 N. Water St, East Pointe Commons',
#     'City': 'Milwaukee',
#     'State': 'WI',
#     'Longitude': -87.91,
#     'Latitude': 43.03},
#    '2524-29615': {'Ownership Type': 'Company Owned',
#     'Street Address': '544 East Ogden Avenue, Ste 500',
#     'City': 'Milwaukee',
#     'State': 'WI',
#     'Longitude': -87.91,
#     'Latitude': 43.05},
#    '76354-96445': {'Ownership Type': 'Licensed',
#     'Street Address': '2600 S 108th St, University Centre',
#     'City': 'Milwaukee',
#     'State': 'WI',
#     'Longitude': -88.04,
#     'Latitude': 43.0},
#    '2363-3351': {'Ownership Type': 'Company Owned',
#     'Street Address': '1610 W Wisconsin Ave, Tenant D',
#     'City': 'Milwaukee',
#     'State': 'WI',
#     'Longitude': -87.93,
#     'Latitude': 43.04},
#    '2268-711': {'Ownership Type': 'Company Owned',
#     'Street Address': '2551 N. Downer Ave',
#     'City': 'Milwaukee',
#     'State': 'WI',
#     'Longitude': -87.88,
#     'Latitude': 43.07},
#    '2706-214584': {'Ownership Type': 'Company Owned',
#     'Street Address': '2500 N Mayfair Road, Space no: 5530, Pier 37',
#     'City': 'Milwaukee',
#     'State': 'WI',
#     'Longitude': -88.04,
#     'Latitude': 43.06},
#    '2655-64679': {'Ownership Type': 'Company Owned',
#     'Street Address': '6512 Monona Drive',
#     'City': 'Monona',
#     'State': 'WI',
#     'Longitude': -89.32,
#     'Latitude': 43.05},
#    '19809-202244': {'Ownership Type': 'Company Owned',
#     'Street Address': 'S69 W15476  Janesville Road',
#     'City': 'Muskego',
#     'State': 'WI',
#     'Longitude': -88.11,
#     'Latitude': 42.92},
#    '10304-100160': {'Ownership Type': 'Company Owned',
#     'Street Address': '1015 W. Winneconne Ave.',
#     'City': 'Neenah',
#     'State': 'WI',
#     'Longitude': -88.48,
#     'Latitude': 44.18},
#    '2695-214206': {'Ownership Type': 'Company Owned',
#     'Street Address': '15550 West National Avenue',
#     'City': 'New Berlin',
#     'State': 'WI',
#     'Longitude': -88.11,
#     'Latitude': 42.98},
#    '20339-204772': {'Ownership Type': 'Licensed',
#     'Street Address': '4798 S Moorland Rd',
#     'City': 'New Berlin',
#     'State': 'WI',
#     'Longitude': -88.11,
#     'Latitude': 42.96},
#    '76325-90366': {'Ownership Type': 'Licensed',
#     'Street Address': '8989 S Howell Ave',
#     'City': 'Oak Creek',
#     'State': 'WI',
#     'Longitude': -87.92,
#     'Latitude': 42.88},
#    '10215-99396': {'Ownership Type': 'Company Owned',
#     'Street Address': '2015 W. Ryan Rd.',
#     'City': 'Oak Creek',
#     'State': 'WI',
#     'Longitude': -87.94,
#     'Latitude': 42.87},
#    '25045-239030': {'Ownership Type': 'Company Owned',
#     'Street Address': '600 W. Drexel Ave, Suite 100',
#     'City': 'Oak Creek',
#     'State': 'WI',
#     'Longitude': -87.92,
#     'Latitude': 42.9},
#    '25252-239824': {'Ownership Type': 'Licensed',
#     'Street Address': '171 W Town Square Way',
#     'City': 'Oak Creek',
#     'State': 'WI',
#     'Longitude': -87.91,
#     'Latitude': 42.89},
#    '8778-94630': {'Ownership Type': 'Company Owned',
#     'Street Address': '8880 South Howell Ave.',
#     'City': 'Oak Creek',
#     'State': 'WI',
#     'Longitude': -87.91,
#     'Latitude': 42.88},
#    '10247-100353': {'Ownership Type': 'Company Owned',
#     'Street Address': '1370 Pabst Farms Circle, Suite 300',
#     'City': 'Oconomowoc',
#     'State': 'WI',
#     'Longitude': -88.47,
#     'Latitude': 43.07},
#    '10993-102227': {'Ownership Type': 'Company Owned',
#     'Street Address': '9432 State Hwy 16, Suite 180',
#     'City': 'Onalaska',
#     'State': 'WI',
#     'Longitude': -91.19,
#     'Latitude': 43.87},
#    '10535-100818': {'Ownership Type': 'Company Owned',
#     'Street Address': '240 W Murdock St',
#     'City': 'Oshkosh',
#     'State': 'WI',
#     'Longitude': -88.54,
#     'Latitude': 44.04},
#    '2883-93174': {'Ownership Type': 'Company Owned',
#     'Street Address': '1150A Koeller St.',
#     'City': 'Oshkosh',
#     'State': 'WI',
#     'Longitude': -88.58,
#     'Latitude': 44.01},
#    '76388-97001': {'Ownership Type': 'Licensed',
#     'Street Address': '1900 S Koeller St, Stone Creek Shops',
#     'City': 'Oshkosh',
#     'State': 'WI',
#     'Longitude': -88.58,
#     'Latitude': 44.0},
#    '2558-41379': {'Ownership Type': 'Company Owned',
#     'Street Address': '1390 CAPITOL DRIVE, Unit #1',
#     'City': 'Pewaukee',
#     'State': 'WI',
#     'Longitude': -88.23,
#     'Latitude': 43.08},
#    '29477-251829': {'Ownership Type': 'Licensed',
#     'Street Address': 'N51 W24953 Lisbon Rd',
#     'City': 'Pewaukee',
#     'State': 'WI',
#     'Longitude': -88.16,
#     'Latitude': 43.1},
#    '13394-106663': {'Ownership Type': 'Company Owned',
#     'Street Address': '9740 76th St, 102',
#     'City': 'Pleasant Prairie',
#     'State': 'WI',
#     'Longitude': -87.93,
#     'Latitude': 42.57},
#    '76996-106136': {'Ownership Type': 'Licensed',
#     'Street Address': '9777 76th St',
#     'City': 'Pleasant Prairie',
#     'State': 'WI',
#     'Longitude': -87.91,
#     'Latitude': 42.52},
#    '10419-100474': {'Ownership Type': 'Company Owned',
#     'Street Address': '120 Crossroads Dr',
#     'City': 'Plover',
#     'State': 'WI',
#     'Longitude': -89.51,
#     'Latitude': 44.5},
#    '14685-125887': {'Ownership Type': 'Company Owned',
#     'Street Address': '2805 South Greenbay Rd.',
#     'City': 'Racine',
#     'State': 'WI',
#     'Longitude': -87.85,
#     'Latitude': 42.7},
#    '2959-83395': {'Ownership Type': 'Company Owned',
#     'Street Address': '5658 Washington Ave., Unit 3',
#     'City': 'Racine',
#     'State': 'WI',
#     'Longitude': -87.85,
#     'Latitude': 42.72},
#    '13991-108499': {'Ownership Type': 'Company Owned',
#     'Street Address': '1026 North 14th Street',
#     'City': 'Sheboygan',
#     'State': 'WI',
#     'Longitude': -87.72,
#     'Latitude': 43.76},
#    '76181-88824': {'Ownership Type': 'Licensed',
#     'Street Address': '4085 State Hwy 28',
#     'City': 'Sheboygan',
#     'State': 'WI',
#     'Longitude': -87.76,
#     'Latitude': 43.71},
#    '10480-100820': {'Ownership Type': 'Company Owned',
#     'Street Address': '3550 Washington Ave Frontage Rd',
#     'City': 'Sheboygan',
#     'State': 'WI',
#     'Longitude': -87.75,
#     'Latitude': 43.72},
#    '47408-254727': {'Ownership Type': 'Licensed',
#     'Street Address': '4075 N Oakland Ave',
#     'City': 'Shorewood',
#     'State': 'WI',
#     'Longitude': -87.89,
#     'Latitude': 43.09},
#    '10768-101864': {'Ownership Type': 'Company Owned',
#     'Street Address': '101 Division Street',
#     'City': 'Stevens Point',
#     'State': 'WI',
#     'Longitude': -89.57,
#     'Latitude': 44.53},
#    '20334-204768': {'Ownership Type': 'Licensed',
#     'Street Address': '410 S. Ashland Avenue',
#     'City': 'Sturgeon Bay',
#     'State': 'WI',
#     'Longitude': -87.4,
#     'Latitude': 44.82},
#    '70365-138021': {'Ownership Type': 'Licensed',
#     'Street Address': '660 South Grand Avenue',
#     'City': 'Sun Prairie',
#     'State': 'WI',
#     'Longitude': -89.27,
#     'Latitude': 43.17},
#    '19808-202245': {'Ownership Type': 'Company Owned',
#     'Street Address': '2804 Prairie Lakes Drive',
#     'City': 'Sun Prairie',
#     'State': 'WI',
#     'Longitude': -89.27,
#     'Latitude': 43.17},
#    '10928-103119': {'Ownership Type': 'Company Owned',
#     'Street Address': 'N65 W24950 Main Street',
#     'City': 'Sussex',
#     'State': 'WI',
#     'Longitude': -88.24,
#     'Latitude': 43.14},
#    '25706-240885': {'Ownership Type': 'Company Owned',
#     'Street Address': '224 Buan Street',
#     'City': 'Tomah',
#     'State': 'WI',
#     'Longitude': -90.51,
#     'Latitude': 44.02},
#    '9807-98204': {'Ownership Type': 'Company Owned',
#     'Street Address': '801 W Moreland Blvd',
#     'City': 'Waukesha',
#     'State': 'WI',
#     'Longitude': -88.24,
#     'Latitude': 43.02},
#    '29758-251827': {'Ownership Type': 'Licensed',
#     'Street Address': '801 E SUNSET DRIVE',
#     'City': 'WAUKESHA',
#     'State': 'WI',
#     'Longitude': -88.22,
#     'Latitude': 42.99},
#    '15512-156754': {'Ownership Type': 'Licensed',
#     'Street Address': '2401 Kossow Rd',
#     'City': 'Waukesha',
#     'State': 'WI',
#     'Longitude': -88.18,
#     'Latitude': 43.03},
#    '3865-140229': {'Ownership Type': 'Licensed',
#     'Street Address': '1250 Sunset Dr',
#     'City': 'Waukesha',
#     'State': 'WI',
#     'Longitude': -88.26,
#     'Latitude': 42.99},
#    '2657-59299': {'Ownership Type': 'Company Owned',
#     'Street Address': '306 S. 17th Avenue',
#     'City': 'Wausau',
#     'State': 'WI',
#     'Longitude': -89.66,
#     'Latitude': 44.96},
#    '11319-102242': {'Ownership Type': 'Company Owned',
#     'Street Address': '4728 Rib Mountain Drive',
#     'City': 'Wausau',
#     'State': 'WI',
#     'Longitude': -89.65,
#     'Latitude': 44.91},
#    '78070-107565': {'Ownership Type': 'Licensed',
#     'Street Address': '1 Mayfair Mall N.',
#     'City': 'Wauwatosa',
#     'State': 'WI',
#     'Longitude': -88.05,
#     'Latitude': 43.07},
#    '2351-7548': {'Ownership Type': 'Company Owned',
#     'Street Address': '12345 West Capitol Drive',
#     'City': 'Wauwatosa',
#     'State': 'WI',
#     'Longitude': -88.07,
#     'Latitude': 43.09},
#    '5113-144972': {'Ownership Type': 'Licensed',
#     'Street Address': '3900 N 124th St',
#     'City': 'Wauwatosa',
#     'State': 'WI',
#     'Longitude': -88.07,
#     'Latitude': 43.09},
#    '25253-239451': {'Ownership Type': 'Licensed',
#     'Street Address': '11111 W Burleigh Street, Mayfair',
#     'City': 'Wauwatosa',
#     'State': 'WI',
#     'Longitude': -88.05,
#     'Latitude': 43.07},
#    '28580-249762': {'Ownership Type': 'Company Owned',
#     'Street Address': '2500 NORTH MAYFAIR RD., #372',
#     'City': 'WAUWATOSA',
#     'State': 'WI',
#     'Longitude': -88.05,
#     'Latitude': 43.06},
#    '2349-3349': {'Ownership Type': 'Company Owned',
#     'Street Address': '1417 N. Wauwatosa Avenue',
#     'City': 'Wauwatosa',
#     'State': 'WI',
#     'Longitude': -88.01,
#     'Latitude': 43.05},
#    '2985-93510': {'Ownership Type': 'Company Owned',
#     'Street Address': '151 N Mayfair Road',
#     'City': 'Wauwatosa',
#     'State': 'WI',
#     'Longitude': -88.05,
#     'Latitude': 43.03},
#    '14410-108213': {'Ownership Type': 'Company Owned',
#     'Street Address': '2751 N Mayfair Rd, A',
#     'City': 'Wauwatosa',
#     'State': 'WI',
#     'Longitude': -88.05,
#     'Latitude': 43.07},
#    '2473-17195': {'Ownership Type': 'Company Owned',
#     'Street Address': '1500 SOUTH 108TH STREET',
#     'City': 'West Allis',
#     'State': 'WI',
#     'Longitude': -88.05,
#     'Latitude': 43.01},
#    '9281-95846': {'Ownership Type': 'Company Owned',
#     'Street Address': '2939 S. 108th St.',
#     'City': 'West Allis',
#     'State': 'WI',
#     'Longitude': -88.05,
#     'Latitude': 42.99},
#    '2617-57219': {'Ownership Type': 'Company Owned',
#     'Street Address': '443 W. Paradise Dr.',
#     'City': 'West Bend',
#     'State': 'WI',
#     'Longitude': -88.18,
#     'Latitude': 43.4},
#    '76244-90367': {'Ownership Type': 'Licensed',
#     'Street Address': '1501 Miller Pkwy',
#     'City': 'West Milwaukee',
#     'State': 'WI',
#     'Longitude': -87.97,
#     'Latitude': 43.02},
#    '8140-178966': {'Ownership Type': 'Company Owned',
#     'Street Address': '1216 Miller Park Way',
#     'City': 'West Milwaukee',
#     'State': 'WI',
#     'Longitude': -87.97,
#     'Latitude': 43.02},
#    '2258-713': {'Ownership Type': 'Company Owned',
#     'Street Address': '302 E. Silver Spring Drive',
#     'City': 'Whitefish Bay',
#     'State': 'WI',
#     'Longitude': -87.91,
#     'Latitude': 43.12},
#    '2718-80221': {'Ownership Type': 'Company Owned',
#     'Street Address': '320 Highway 13, Huntington Mall',
#     'City': 'Wisconsin Dells',
#     'State': 'WI',
#     'Longitude': -89.79,
#     'Latitude': 43.62}}},
#  'Wyoming': {'Labor Force': 291048,
#   'Personal Income Capital': 57516,
#   'Stores': {'21239-210245': {'Ownership Type': 'Company Owned',
#     'Street Address': '560 N Center Street',
#     'City': 'Casper',
#     'State': 'WY',
#     'Longitude': -106.33,
#     'Latitude': 42.86},
#    '9619-97642': {'Ownership Type': 'Company Owned',
#     'Street Address': '4585 East 2nd St.',
#     'City': 'Casper',
#     'State': 'WY',
#     'Longitude': -106.26,
#     'Latitude': 42.85},
#    '79668-108627': {'Ownership Type': 'Licensed',
#     'Street Address': '300 E Wyoming Blvd',
#     'City': 'Casper',
#     'State': 'WY',
#     'Longitude': -106.27,
#     'Latitude': 42.85},
#    '11862-103659': {'Ownership Type': 'Company Owned',
#     'Street Address': '4003 Cy Ave',
#     'City': 'Casper',
#     'State': 'WY',
#     'Longitude': -106.37,
#     'Latitude': 42.82},
#    '28265-237406': {'Ownership Type': 'Licensed',
#     'Street Address': '3702 Dell Range Blvd',
#     'City': 'Cheyenne',
#     'State': 'WY',
#     'Longitude': -104.76,
#     'Latitude': 41.16},
#    '74427-94041': {'Ownership Type': 'Licensed',
#     'Street Address': '700 S Greeley Hwy',
#     'City': 'Cheyenne',
#     'State': 'WY',
#     'Longitude': -104.8,
#     'Latitude': 41.11},
#    '73370-24376': {'Ownership Type': 'Licensed',
#     'Street Address': '3355 E. Pershing Blvd.',
#     'City': 'Cheyenne',
#     'State': 'WY',
#     'Longitude': -104.77,
#     'Latitude': 41.14},
#    '73277-27188': {'Ownership Type': 'Licensed',
#     'Street Address': '5800 Yellowstone Rd.',
#     'City': 'Cheyenne',
#     'State': 'WY',
#     'Longitude': -104.83,
#     'Latitude': 41.17},
#    '29314-251304': {'Ownership Type': 'Company Owned',
#     'Street Address': '5930Yellowstone Rd',
#     'City': 'Cheyenne',
#     'State': 'WY',
#     'Longitude': -104.83,
#     'Latitude': 41.17},
#    '11082-102939': {'Ownership Type': 'Company Owned',
#     'Street Address': '2111 Central Ave, Dell Range Marketplace',
#     'City': 'Cheyenne',
#     'State': 'WY',
#     'Longitude': -104.82,
#     'Latitude': 41.14},
#    '6515-63127': {'Ownership Type': 'Company Owned',
#     'Street Address': '3610 Dell Range Boulevard, Unit A6',
#     'City': 'Cheyenne',
#     'State': 'WY',
#     'Longitude': -104.77,
#     'Latitude': 41.16},
#    '17716-126790': {'Ownership Type': 'Licensed',
#     'Street Address': '1825 17th St',
#     'City': 'Cody',
#     'State': 'WY',
#     'Longitude': -109.05,
#     'Latitude': 44.52},
#    '73334-24378': {'Ownership Type': 'Licensed',
#     'Street Address': '2610 S. Douglas Hwy.',
#     'City': 'Gillette',
#     'State': 'WY',
#     'Longitude': -105.49,
#     'Latitude': 44.27},
#    '11320-103719': {'Ownership Type': 'Company Owned',
#     'Street Address': '1215 S Douglas Hwy',
#     'City': 'Gillette',
#     'State': 'WY',
#     'Longitude': -105.49,
#     'Latitude': 44.28},
#    '19240-195904': {'Ownership Type': 'Company Owned',
#     'Street Address': '10 East Broadway',
#     'City': 'Jackson',
#     'State': 'WY',
#     'Longitude': -110.76,
#     'Latitude': 43.48},
#    '16502-171825': {'Ownership Type': 'Licensed',
#     'Street Address': '105 Buffalo Way',
#     'City': 'Jackson',
#     'State': 'WY',
#     'Longitude': -110.79,
#     'Latitude': 43.47},
#    '18274-101208': {'Ownership Type': 'Licensed',
#     'Street Address': 'South Hwy 89 High School Rd',
#     'City': 'Jackson Hole',
#     'State': 'WY',
#     'Longitude': -110.75,
#     'Latitude': 43.48},
#    '22353-220004': {'Ownership Type': 'Licensed',
#     'Street Address': '1165 Main St.',
#     'City': 'Lander',
#     'State': 'WY',
#     'Longitude': -108.75,
#     'Latitude': 42.84},
#    '74385-87621': {'Ownership Type': 'Licensed',
#     'Street Address': '554 N 3rd St',
#     'City': 'Laramie',
#     'State': 'WY',
#     'Longitude': -105.59,
#     'Latitude': 41.32},
#    '73320-24375': {'Ownership Type': 'Licensed',
#     'Street Address': '3112 E. Grand',
#     'City': 'Laramie',
#     'State': 'WY',
#     'Longitude': -105.56,
#     'Latitude': 41.31},
#    '22425-219024': {'Ownership Type': 'Company Owned',
#     'Street Address': '3021 Grand Ave',
#     'City': 'Laramie',
#     'State': 'WY',
#     'Longitude': -105.56,
#     'Latitude': 41.31},
#    '10849-103163': {'Ownership Type': 'Company Owned',
#     'Street Address': '118 Westland Way',
#     'City': 'Rock Springs',
#     'State': 'WY',
#     'Longitude': -109.25,
#     'Latitude': 41.58},
#    '10769-102454': {'Ownership Type': 'Company Owned',
#     'Street Address': '2208 Coffeen Ave',
#     'City': 'Sheridian',
#     'State': 'WY',
#     'Longitude': -106.94,
#     'Latitude': 44.77}}}}
